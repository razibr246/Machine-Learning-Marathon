# %%
import pandas as pd
import numpy as np

data = np.array(['g', 'e', 'e', 'k', 's'])
s = pd.Series(data)
print("Pandas Series:")
print(s)
# Out:
# Pandas Series:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import pandas as pd

df = pd.DataFrame()
print(df)
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']

df = pd.DataFrame(lst)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df.head())
# Out:
#     name  age     city category  sales  a   b
# 0   John   25    Delhi        A    200  5  10
# 1   Riya   22   Mumbai        B    120  2   3
# 2   Aman   30     Pune        A    250  7   8
# 3   Neha   27  Kolkata        C    300  4   6
# 4  Arjun   35   Jaipur        B    200  1   9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5 non-null      object
#  1   age       5 non-null      int64
#  2   city      5 non-null      object
#  3   category  5 non-null      object
#  4   sales     5 non-null      int64
#  5   a         5 non-null      int64
#  6   b         5 non-null      int64
# dtypes: int64(4), object(3)
# memory usage: 412.0+ bytes

# %%
print(df.isnull().sum())
df = df.fillna(0)
# Out:
# name        0
# age         0
# city        0
# category    0
# sales       0
# a           0
# b           0
# dtype: int64

# %%
ages = df[df['age'] > 25]
print(ages)
# Out:
#     name  age     city category  sales  a  b
# 2   Aman   30     Pune        A    250  7  8
# 3   Neha   27  Kolkata        C    300  4  6
# 4  Arjun   35   Jaipur        B    200  1  9

# %%
df['total'] = df['a'] + df['b']
print(df.head())
# Out:
#     name  age     city category  sales  a   b  total
# 0   John   25    Delhi        A    200  5  10     15
# 1   Riya   22   Mumbai        B    120  2   3      5
# 2   Aman   30     Pune        A    250  7   8     15
# 3   Neha   27  Kolkata        C    300  4   6     10
# 4  Arjun   35   Jaipur        B    200  1   9     10

# %%
df['res'] = df.groupby('category')['sales'].sum()

print(res)
# Out:
# category
# A    450
# B    320
# C    300
# Name: sales, dtype: int64

# %%
print(df.head())
# Out:
#     name  age     city category  sales  a   b  total  res
# 0   John   25    Delhi        A    200  5  10     15  NaN
# 1   Riya   22   Mumbai        B    120  2   3      5  NaN
# 2   Aman   30     Pune        A    250  7   8     15  NaN
# 3   Neha   27  Kolkata        C    300  4   6     10  NaN
# 4  Arjun   35   Jaipur        B    200  1   9     10  NaN

# %% [markdown]
# #Pandas DataFrame

# %%
import pandas as pd
names = ["Aparna", "Pankaj", "Sudhir", "Garvit"]
degrees = ["MBA", "BCA", "MTech", "MBA"]
scores = [90, 40, 80, 98]

df = pd.DataFrame({'Name': names, 'Degree': degrees, 'Score': scores})
print(df)
# Out:
#      Name Degree  Score
# 0  Aparna    MBA     90
# 1  Pankaj    BCA     40
# 2  Sudhir  MTech     80
# 3  Garvit    MBA     98

# %%
names = ["Aparna","Pankaj","Sudhir","Geeku"]
values = [11,22,33,44]
df = pd.DataFrame(list(zip(names,values)),columns= ['Name','Value'])

print(df)
# Out:
#      Name  Value
# 0  Aparna     11
# 1  Pankaj     22
# 2  Sudhir     33
# 3   Geeku     44

# %%
data = [['Tom',34],['Krsih',35],['Nick',88],['Juli',99]]


df = pd.DataFrame(data,columns=['Names','age'])
print(df)
# Out:
#    Names  age
# 0    Tom   34
# 1  Krsih   35
# 2   Nick   88
# 3   Juli   99

# %%
import pandas as pd
data = [['Tom', 'Reacher', 25], ['Krish', 'Pete', 30], ['Nick', 'Wilson', 26], ['Juli', 'Williams', 22]]
df = pd.DataFrame(data, columns=['FName', 'LName', 'Age'])
df['Age'] = df['Age'].astype(float)
print(df)
# Out:
#    FName     LName   Age
# 0    Tom   Reacher  25.0
# 1  Krish      Pete  30.0
# 2   Nick    Wilson  26.0
# 3   Juli  Williams  22.0

# %%
import pandas as pd
data = ["Aparna", "Pankaj", "Sudhir", "Garvit"]
df = pd.DataFrame(data, index=['a', 'b', 'c', 'd'], columns=['Names'])
print(df)
# Out:
#     Names
# a  Aparna
# b  Pankaj
# c  Sudhir
# d  Garvit

# %%
import pandas as pd
data = [1, 2, 3, 4, 5]
df = pd.DataFrame(data, columns=['Numbers'])
print(df)
# Out:
#    Numbers
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
import pandas as pd

lst = ['Geeks', 'For', 'Geeks', 'is',
            'portal', 'for', 'Geeks']

df = pd.DataFrame(lst)
print(df)
# Out:
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %% [markdown]
# #Working With Rows and Columns in Pandas DataFrame

# %%
import pandas as pd

data = {'Name' : ['Jai','Princi','Gaurav','Anuj'],
        'age'  : [ 27,28,22,34],
        'Address' : ['Delhi','Kanpur','Dhaka','Rangpur'],
        'Qualification' : ['Msc','MA','BSc','Phd']
        }

df = pd.DataFrame(data)

print(df[['Name','Qualification']])
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           BSc
# 3    Anuj           Phd

# %%
data = pd.read_csv("nba.csv",index_col = "Name")
data
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0
# ...                          ...        ...
# Shelvin Mack              Butler  2433333.0
# Raul Neto                    NaN   900000.0
# Tibor Pleiss                 NaN  2900000.0
# Jeff Withey               Kansas   947276.0
# NaN                          NaN        NaN
#
# [458 rows x 8 columns]

# %%
first = data.loc["Avery Bradley"]
second = data.loc['R.J. Hunter']


print(first,"\n\n\n", second)
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
#
#  Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
import pandas as pd

data = pd.read_csv("/content/nba.csv", index_col ="Name")

first = data["Age"]

print(first)
# Out:
# Name
# Avery Bradley    25.0
# Jae Crowder      25.0
# John Holland     27.0
# R.J. Hunter      22.0
# Jonas Jerebko    29.0
#                  ...
# Shelvin Mack     26.0
# Raul Neto        24.0
# Tibor Pleiss     26.0
# Jeff Withey      26.0
# NaN               NaN
# Name: Age, Length: 458, dtype: float64

# %%
import pandas as pd

data = pd.read_csv("/content/nba.csv", index_col ="Name")

row2 = data.iloc[3]

print(row2)
# Out:
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
import pandas as pd

import numpy as np

dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

df = pd.DataFrame(dict)

print(df.isnull())
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
import pandas as pd

import numpy as np

dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)

print(df.fillna(0))
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
import pandas as pd

import numpy as np

dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

df = pd.DataFrame(dict)

print(df)
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
import pandas as pd

import numpy as np

dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}
df = pd.DataFrame(dict)

print(df.dropna())
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %%
import pandas as pd
import numpy as np

data = np.array(['g', 'e', 'e', 'k', 's'])
s = pd.Series(data)
print("Pandas Series:")
print(s)
# Out:
# Pandas Series:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import pandas as pd

df = pd.DataFrame()
print(df)
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']

df = pd.DataFrame(lst)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df.head())
# Out:
#     name  age     city category  sales  a   b
# 0   John   25    Delhi        A    200  5  10
# 1   Riya   22   Mumbai        B    120  2   3
# 2   Aman   30     Pune        A    250  7   8
# 3   Neha   27  Kolkata        C    300  4   6
# 4  Arjun   35   Jaipur        B    200  1   9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5 non-null      object
#  1   age       5 non-null      int64
#  2   city      5 non-null      object
#  3   category  5 non-null      object
#  4   sales     5 non-null      int64
#  5   a         5 non-null      int64
#  6   b         5 non-null      int64
# dtypes: int64(4), object(3)
# memory usage: 412.0+ bytes

# %%
print(df.isnull().sum())
df = df.fillna(0)
# Out:
# name        0
# age         0
# city        0
# category    0
# sales       0
# a           0
# b           0
# dtype: int64

# %%
ages = df[df['age'] > 25]
print(ages)
# Out:
#     name  age     city category  sales  a  b
# 2   Aman   30     Pune        A    250  7  8
# 3   Neha   27  Kolkata        C    300  4  6
# 4  Arjun   35   Jaipur        B    200  1  9

# %%
df['total'] = df['a'] + df['b']
print(df.head())
# Out:
#     name  age     city category  sales  a   b  total
# 0   John   25    Delhi        A    200  5  10     15
# 1   Riya   22   Mumbai        B    120  2   3      5
# 2   Aman   30     Pune        A    250  7   8     15
# 3   Neha   27  Kolkata        C    300  4   6     10
# 4  Arjun   35   Jaipur        B    200  1   9     10

# %%
res = df.groupby('category')['sales'].sum()
print(res)
# Out:
# category
# A    450
# B    320
# C    300
# Name: sales, dtype: int64
